# %%
# Contoh comment variable
a = 10 #Integer
b = 3.14 #Float
c = "abc" #String kutip 2 maupun 1
d = 'abc'
e = True #Boolean
f = False #Foolean
k = [] #List
l = [1,2,3] #List
m =  {} #Dictinoary
n = () #Tuple

#Print fungsi utama/berguna untuk Debug

# %%
print(c)
tempat = "indo"
umur = 15
# Out:
# abc

# %%
#Concatination
print("nama " + c)
print("nama {}".format(c))
# Out:
# nama abc
# nama abc

# %%
#input kata
nama = input()
# Out:
# abcdef

# %%
print("Hai, namaku adalah " + nama + ", umurku " + str(umur))
print("Hai, namaku adalah ", nama ,", umurku ", umur)
print("Hai, namaku adalah {}, umurku {}, saya tinggal di {}".format(nama, umur, tempat)) #Recommended
print("nama {}, umur {}".format(nama,umur))
# Out:
# Hai, namaku adalah abcdef, umurku 15
# Hai, namaku adalah  abcdef , umurku  15
# Hai, namaku adalah abcdef, umurku 15, saya tinggal di indo
# nama abcdef, umur 15

# %%
if a == 10:
  print("a sama dengan 10")
elif a > 10:
  print("a lebih dari 10")
else:
  print("a kurang dari 10")
print("ini diluar if")
# Out:
# a sama dengan 10
# ini diluar if

# %%
import math
a = 10
b = 10
#If else

## Conditional Statement
a == b
a != b
a < b
a <= b
a > b
a >= b
True and True
False or True 

##Operator
a + b
a - b
a * b
a / b # 10 / 10 = 1.0 --> Float Division
a // b # 10 // 10 = 1 --> Integer Division
a ** b # 10^10 = 100
a % b # Modulus
a ** (1/2) # akar variable a, dimana a = 10
math.sqrt(a) # akar variabel a
math.sin(a)
math.tan(a)
math.cos(a)
math.tanh(a)
math.sinh(a)
math.cosh(a)
math.log(a)
